# %%
import requests 
from bs4 import BeautifulSoup
import re
import pandas as pd
import time as timetime
from selenium import webdriver
import urllib
from tqdm.notebook import tqdm_notebook

# %%
## 청정원레시피
def get_recipe1(have_list) :
    recipe = []
    url_list=[]
    
    ## 사이트안에서 가진 재료를 입력했을때의 레시피 리스트 접속
    for i, val in enumerate(have_list) :
        if i == 0 :
            url_list.append(val)
        else :
            a = "+"
            b = a + val
            url_list.append(b)
    url_str = ''.join(url_list)
    resp = requests.request("GET", "http://www.chungjungone.com/knowhow/recipe/recipeListNew.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0".format(url_str)) 
    soup = BeautifulSoup(resp.text)
    find_ul = soup.find('ul', class_ = 'recipe_ul fourList')
    
    ## 관련 레시피리스트가 없을 경우
    if find_ul is None :
        recipe.append({
                'title' : "",
                'url' : "",
                'time' : "",
                'level' : "",
                'ingredient' : ""
            })
        return recipe
    else :
        find_li = find_ul.find_all('li')

    ## url 가져오기
    recipe_url = []
    for i in find_li :
        find_a = i.find('a')
        url = find_a.get('onclick')
        url = str(url)
        url_ = re.findall("\d+", url)
        recipe_url.append(url_[-1])

    ## title 가져오기
    for i in recipe_url :
        try:
            url_num = i
            resp = requests.request("GET", 'http://www.chungjungone.com/knowhow/recipe/recipeView1New.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0&recp_seq={}'.format(url_str,url_num)) 
            soup = BeautifulSoup(resp.text)
            find_div = soup.find('div', class_ = 'editRecipy')
            find_h2 = find_div.find('h2')
            title = find_h2.text

            find_ul = soup.find('ul', class_ = 'reInfo')
            span_list = []
            for i in find_ul :
                find_span = i.find('span')
                span_list.append(find_span)

            ## keyword 가져오기(몇분/난이도)
            keyword = []
            for i in span_list[1:8:2] :
                i = str(i)
                i = i[6:]
                i = i.split('<')
                data = i[0]
                if '조리' in data:
                    i = data[3:]
                    keyword.append(i)
                else :
                    keyword.append(data)

            for i in keyword :
                if "분" in i :
                    if '인' not in i :
                        time = i
                elif ("급") in i :
                    level = i
                else :
                    pass

            # 재료 가져오기

            source = []
            find_div = soup.find('div', class_ = 'texAlCenter')
            find_div = str(find_div)
            find_div = find_div.replace('<br/>', ',').replace('</div>', '').replace('<div class="texAlCenter">', '').replace(':', ',').replace(',,', ',')
            source.append(find_div)

            list_ = source[0].split(',')
            for i in list_ :
                if '소스' in i :
                    list_.remove(i)
            ingredient = []
            for i in list_ :
                i = i.strip()
                if len(i) == 0 :
                    pass
                else : 
                    ingredient.append(i)
                    
            recipe.append({
                'title' : title,
                'url' : 'http://www.chungjungone.com/knowhow/recipe/recipeView1New.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0&recp_seq={}'.format(url_str,url_num),
                'time' : time,
                'level' : level,
                'ingredient' : ingredient
            })

        except :
            continue

    return recipe


##만개의 레시피
def get_recipe2(have_list):
    
    base_url='https://www.10000recipe.com/recipe/list.html'

    have_list1 = "+".join(have_list) 
    food = " ".join(have_list)
    
    params={
        'q':food
    }
    
    resp=requests.get(base_url,params=params)
    soup=BeautifulSoup(resp.text)    
    
    
    url_list=[]
    title_list=[]
    result_list=[]
    
    recipe_list_tags=soup.select('ul.common_sp_list_ul.ea4')
    li_tags=recipe_list_tags[0].find_all('li')

    
    for li in tqdm_notebook(li_tags):
        anchor_tag=li.find('a')
        href=anchor_tag.get('href')
        title_tag=li.find_all('div',class_='common_sp_caption_tit line2')
        
        result_list.append({'title':title_tag,
                           'url':href})
        
        url_list.append(href)
        for title in title_tag:
            title_list.append(title.text.strip())
    
    
    url_list2=[]
    for url in url_list:
        each_url='https://www.10000recipe.com'+url
        url_list2.append(each_url)
        
    span1=[]
    span2=[]
    span3=[]
    for url in tqdm_notebook(url_list):
        each_url='https://www.10000recipe.com'+url

        resp=requests.get(each_url)
        soup=BeautifulSoup(resp.text)

        desc_list_tags=soup.select('div.view2_summary_info')

        for desc in desc_list_tags:
            span_tag=desc.select('span')
            if len(span_tag) == 3:
                time = span_tag[1].text
                lev = span_tag[2].text
                span2.append(time)
                span3.append(lev)
            
            elif not span_tag:
                span2.append(None)
                span3.append(None)

            else:
                time=None
                lev = span_tag[0]
                span2.append(time)
                span3.append(lev)

    ing_list=[]
    li_list=[]
    for url in url_list:
        each_url='https://www.10000recipe.com'+url

        resp=requests.get(each_url)
        soup=BeautifulSoup(resp.text)

        ing_list_tags=soup.select('div.ready_ingre3')
        cont_tags=soup.select('div.cont_ingre')

        for i in ing_list_tags:
            li_tags=i.find_all('li')
            li_list.append(li_tags)

        for j in cont_tags:
            dd_tags=j.find_all('dd')
            li_list.append(dd_tags)
            
    ingr_list=[]
    for i in tqdm_notebook(li_list):
        temp = []
        for j in i:
            all_ing=j.text.replace(' ','').strip().split('\n')
            all_ing = " ".join(all_ing)
            temp.append(all_ing)
        ingr_list.append(temp) 
        temp=[]
        
    df=pd.DataFrame({'title':title_list,
                     'url':url_list2,
                     'time':span2,
                     'level':span3,
                     'ingredient':ingr_list})
    
    return df

## 해먹남녀
def get_recipe3(have_list,page_num=2):
    have_list1 = "+".join(have_list) ## "양파 가지"
    have_list2 = " ".join(have_list)
    url = 'https://www.haemukja.com/recipes?utf8=%E2%9C%93&sort=rlv&name={}'.format(have_list1)
    result_list = []
    
    for i in range(page_num):
        params = {
            'name': have_list2,
            'page': 1,
            'sort': 'rlv'
         }

        resp = requests.get(url, params = params)
        resp

        soup = BeautifulSoup(resp.text)

        titles = soup.select('ul.lst_recipe>li>p>a')

        for a_tag in titles:

            recipe_url = 'https://www.haemukja.com'+ a_tag.get('href')
            detail_resp = requests.get(recipe_url)
            html = BeautifulSoup(detail_resp.text)

            prd_time = str(html.select('div.top>dl>dd'))
            prd_time = re.sub('<.+?>', '', prd_time, 0).strip()
            prd_sources = str(html.select('div.btm>ul>li'))
            prd_sources=re.sub('<.+?>', '', prd_sources,0)

            result_list.append({
                'title': (a_tag.text.split('\n')[1]).strip(),
                'url': recipe_url,
                'time':prd_time.replace('[','').replace(']','').split(',')[0],
                'level': 'null',
                'ingredient': prd_sources.replace('[','').replace(']','').split(',')
            })       

        return result_list 

have_list = []
have = input("가진 재료 :")
while have != '끝' :
    have_list.append(have)
    have = input("가진 재료 :")
    
## 각 함수들의 리턴값인 데이터프레임형태의 레시피리스트를 concat하여 하나의 데이터프레임으로 저장
data1 = get_recipe1(have_list)
data1 = pd.DataFrame(data1)
data2 = get_recipe2(have_list)
data3 = get_recipe3(have_list)
data3 = pd.DataFrame(data3)
if len(data1['title'][0]) == 0 :
    menu = pd.concat([data2,data3])
else :
    menu = pd.concat([data1,data2,data3])
menu.reset_index(drop=True,inplace=True)
menu ## 최종 레시피 리스트
# Out:
# 가진 재료 :계란
# 가진 재료 :시금치
# 가진 재료 :끝
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
#                                                 title  \
# 0                     매콤소고기김밥 황금레시피 담백하고 매콤한 소고기볶음 가득
# 1                   [홈메이드 이탈리아 푸드] 고추장 딥핑소스를 곁들인 두부튀김
# 2                                      베트남식 볶음쌀국수 퍼싸오
# 3                                       백종원의 부추 달걀 볶음
# 4                               간단요리 계란 양파덮밥 혼밥 자취레시피
# 5                                      매콤 소시지 달걀 치즈구이
# 6          백종원 부추 달걀 볶음 황금레시피 ,, 초간단 중국식 인기 메뉴 맛있어요~!
# 7                      초간단 아침식사, 카레향 나는 두부 달걀 스크램블 덮밥
# 8                                한그릇요리, 시금치 갈릭 새우 볶음밥
# 9                               완전 초간단 초간편 시금치 스팸햄 볶음
# 10                                       당면 계란 만두 전~*
# 11                       계란 새우볶음밥 만들기 굴소스로 쉽게 만들어요 ^^
# 12                                계란 참치주먹밥 소풍도시락 간단요리
# 13                           술술 부드럽게 넘어가는 우유 계란 카레 덮밥
# 14                             숙주요리 계란 새우 숙주볶음 초간단반찬!
# 15                          식빵 토스트, 든든한 소시지 달걀 치즈 토스트
# 16  초간단 다이어트 요리!! 양배추 계란 덮밥 만들기 (단백질 40.89kcal, 지방...
# 17                               초간단 원팬 다이어트 시금치 프리타타
# 18        간단한 볶음요리!집밥 백선생의 부추 달걀 볶음레시피! 중국식 계란볶음만들봐요~
# 19                             버터링 쿠키(노에그, 계란 없이 베이킹)
# 20                                    사과 달걀 스크램블 브런치로
# 21                                ♥[정월대보름 한끼] 시금치 파스타
# 22                       여름제철 감자요리/간단 브런치로 좋은 계란 감자채전
# 23                                          쇠고기 달걀 덮밥
# 24                                         소시지 달걀 치즈전
# 25                             계란찜보다 더 맛있는 "시금치프리타타"♪
# 26                                   시금치 요리 / 시금치 겉절이
# 27                              카레향 솔솔 나는 시금치 달걀 카레죽♪
# 28                            간단 5분 요리 계란 크래미 게맛살 볶음밥
# 29                                 백종원 레시피 계란 덮밥 만들기!
# 30                           계란 치즈 볶음밥, 아침메뉴, 초간단 볶음밥
# 31                          달걀 연유 토스트 - 아이 간식 토스트 만들기
# 32                                         스팸햄 계란 볶음밥
# 33            【10분 완성】초간단 영양가득 한그릇 - 대파 계란 볶음밥 만드는 법!
# 34                            초간단 일본식 계란 덮밥, 텐신항, 텐신동
# 35                                         소시지 달걀 볶음밥
# 36                                        청양마요 계란 토스트
# 37                                  간단한 중국풍 표고버섯 계란 국
# 38                                           시금치 된장무침
# 39                          시판 카레로 만드는 시금치 카레, 팔락 파니르
# 40  우아한 브런치, 크림소스를 곁들인 시금치 롤 (Spinach roll with cr...
# 41                               간단한 한끼 :: 베이컨 계란 볶음밥
# 42                                           미역 달걀 말이
# 43                             '다해요_오늘 뭐 먹지'에 소개된 레시피
# 44                              녹색친구랑 친해져요, 우리 아이를 위한
# 45                                               섬초무침
# 46                                     한식 기초 요리 시금치무침
# 47                                   삼색신호등이 왔어요, 삼색나물
# 48                                  우리 아이를 위한 중기 이유식!
# 49                            초간단 영양 만점 밑반찬! 시금치 달걀볶음
# 50                                            시금치 샐러드
# 51                우리 아이가 너무 좋아하는 비쥬얼만큼 맛도 엄청난 새우 시...
# 52                                시금치가 듬뿍 들어간 시금치 라자냐
# 53                                          초간단 황금레시피
# 54                           시금치 베이컨 샐러드 with 요거트 드레싱
#
#                                                   url    time  level  \
# 0   http://www.chungjungone.com/knowhow/recipe/rec...     40분     중급
# 1   http://www.chungjungone.com/knowhow/recipe/rec...     30분     초급
# 2   http://www.chungjungone.com/knowhow/recipe/rec...     50분     초급
# 3          https://www.10000recipe.com/recipe/6891606  15분 이내    아무나
# 4          https://www.10000recipe.com/recipe/6920148  10분 이내    아무나
# 5          https://www.10000recipe.com/recipe/6916782   5분 이내    아무나
# 6          https://www.10000recipe.com/recipe/6871467  10분 이내    아무나
# 7          https://www.10000recipe.com/recipe/6908353  10분 이내    아무나
# 8          https://www.10000recipe.com/recipe/6929581  10분 이내    아무나
# 9          https://www.10000recipe.com/recipe/6908099  10분 이내    아무나
# 10         https://www.10000recipe.com/recipe/6865345  15분 이내    아무나
# 11         https://www.10000recipe.com/recipe/6891445  15분 이내     초급
# 12         https://www.10000recipe.com/recipe/6920843  10분 이내     초급
# 13         https://www.10000recipe.com/recipe/6926683  10분 이내     초급
# 14         https://www.10000recipe.com/recipe/6890250  15분 이내    아무나
# 15         https://www.10000recipe.com/recipe/6911250  10분 이내    아무나
# 16         https://www.10000recipe.com/recipe/6932039  20분 이내    아무나
# 17         https://www.10000recipe.com/recipe/6930102  10분 이내     초급
# 18         https://www.10000recipe.com/recipe/6898178   5분 이내    아무나
# 19         https://www.10000recipe.com/recipe/6876723  60분 이내    아무나
# 20         https://www.10000recipe.com/recipe/6923152  10분 이내    아무나
# 21         https://www.10000recipe.com/recipe/6925914  30분 이내     초급
# 22         https://www.10000recipe.com/recipe/6894202  30분 이내     초급
# 23         https://www.10000recipe.com/recipe/4195367    None  [아무나]
# 24         https://www.10000recipe.com/recipe/6914883  10분 이내    아무나
# 25         https://www.10000recipe.com/recipe/6907878  30분 이내    아무나
# 26         https://www.10000recipe.com/recipe/6924709  15분 이내    아무나
# 27         https://www.10000recipe.com/recipe/6871302  30분 이내    아무나
# 28         https://www.10000recipe.com/recipe/6928754   5분 이내    아무나
# 29         https://www.10000recipe.com/recipe/6833211  15분 이내     초급
# 30         https://www.10000recipe.com/recipe/6854270   5분 이내     초급
# 31         https://www.10000recipe.com/recipe/6908834  60분 이내    아무나
# 32         https://www.10000recipe.com/recipe/6882785  15분 이내     초급
# 33         https://www.10000recipe.com/recipe/6883128  10분 이내     중급
# 34         https://www.10000recipe.com/recipe/6829107  30분 이내     초급
# 35         https://www.10000recipe.com/recipe/3927423  15분 이내    아무나
# 36         https://www.10000recipe.com/recipe/6898226  30분 이내    아무나
# 37         https://www.10000recipe.com/recipe/6884982  10분 이내    아무나
# 38         https://www.10000recipe.com/recipe/6919799  60분 이내    아무나
# 39         https://www.10000recipe.com/recipe/6829333  60분 이내     중급
# 40         https://www.10000recipe.com/recipe/6858483  30분 이내     중급
# 41         https://www.10000recipe.com/recipe/6933621  20분 이내     초급
# 42         https://www.10000recipe.com/recipe/3993622  30분 이내     초급
# 43              https://www.haemukja.com/recipes/5669     30분   null
# 44              https://www.haemukja.com/recipes/4567     30분   null
# 45               https://www.haemukja.com/recipes/211     20분   null
# 46              https://www.haemukja.com/recipes/4236     10분   null
# 47              https://www.haemukja.com/recipes/4500           null
# 48              https://www.haemukja.com/recipes/3935     30분   null
# 49              https://www.haemukja.com/recipes/4284     15분   null
# 50               https://www.haemukja.com/recipes/915     15분   null
# 51              https://www.haemukja.com/recipes/4763     15분   null
# 52              https://www.haemukja.com/recipes/5120     30분   null
# 53              https://www.haemukja.com/recipes/3992     10분   null
# 54              https://www.haemukja.com/recipes/1761     20분   null
#
#                                            ingredient
# 0   [청정원 구운 김밥용 김 6장, 밥 적당량, 햄 6줄, 맛살 3개, 사각어묵 2장,...
# 1                                              [None]
# 2   [라이스누들 80g, 다진 돼지고기 100g, 자색양파 1/4개, 시금치 3줄기, ...
# 3    [부추 1줌, 달걀 4개, 식용유 2큰술, 밥 2공기, 굴소스 1큰술, 참기름 1큰술]
# 4     [양파 1/2개, 계란 2개, 간장 2스푼, 맛술 2스푼, 설탕 1스푼, 물 6스푼]
# 5   [비엔나소시지 8개, 달걀 1개, 청양고추 1개, 다진양파 3큰술, 식용유 1큰술,...
# 6           [계란 3개, 부추 1줌, 굴소스 1큰술, 참기름 1큰술, 식용유 적당량]
# 7   [두부 1모, 달걀 8개, 카레가루 2T, 우유 200ml, 소금 4꼬집, 후추 취...
# 8   [시금치 1줌, 새우 1/2컵, 밥 1그릇, 식용유 3큰술, 진간장 1큰술, 다진마...
# 9   [스팸햄 1/2캔, 시금치 2~3포기, 청양고추 1개, 홍고추 1개, 대파 1큰술,...
# 10            [당면50g,계란2개,대파반,당근조금, 굴소스(티스푼)1,후추(톡톡)]
# 11  [밥 2공기, 양파 1/2개, 대파 1/2대, 당근 1/3개, 계란 3개, 굴소스 ...
# 12  [밥 1공기, 참치한캔 100g, 계란 2개, 소금 3꼬집, 후추 1/2스푼, 대파...
# 13  [카레가루 3~3+1/2스푼, 우유 200ml, 계란 1개, 양파 1/2개, 햄 1...
# 14  [숙주 2-3줌, 계란 2개, 새우 10마리, 양파 1/2개, 청양고추 1개, 대파...
# 15  [식빵 1장, 버터 1큰술, 달걀 1개, 채썬당근 2꼬집, 송송썬파 2꼬집, 모짜렐...
# 16  [현미밥 1/2개, 계란 1개, 닭가슴살소세지 1팩, 양배추 1/4개, 칵테일새우 ...
# 17  [계란 3개, 시금치 1줌, 양파 1/2개, 고구마 1개, 토마토 1/2개, 소금 ...
# 18            [달걀 3개, 부추 1줌, 굴소스 1T, 참기름 1/2T, 후추 약간]
# 19                   [박력분 80g, 설탕 30g, 버터 60g, 우유 2T]
# 20  [달걀 2개, 사과 1/4개, 모짜렐라치즈 60g, 파슬리가루 약간, 식용유 약간,...
# 21  [파스타면 2인분, 시금치 1/2단, 통마늘 7~10개, 올리브오일 적당히, 굴소스...
# 22  [감자 2개, 계란 2개, 슬라이스치즈 1장, 소금 1꼬집, 후추 약간, 찹쌀가루 ...
# 23  [소고기불고기감 100g, 양파주먹크기 1/2개, 대파 2/3개, 달걀 2개, 팽이...
# 24  [남양3층카야치즈 1장, 달걀 2개, 그릴비엔나소시지 4개, 대파 약간, 식용유 약...
# 25  [계란 5개, 시금치 2뿌리(30g), 당근 30g, 양파 1/4조각, 비엔나소세지...
# 26  [시금치 200g, 다진마늘 1/2Ts, 고춧가루 2Ts, 식초 2Ts, 설탕 1T...
# 27  [찬밥 2공기, 시금치 2줌, 달걀 2개, 새송이버섯 1개, 양파 1/2개, 당근 ...
# 28                [크래미 2-3개, 대파 1/2개, 굴소스 1스푼, 계란 1개]
# 29                   [계란 3알, 진간장 2스푼, 고추가루 1스푼, 파 1대]
# 30       [달걀 2개, 치즈 1장, 식용유 2T, 맛소금 약간, 후추 약간, 간장 1T]
# 31                  [식빵 4장, 달걀 2개, 우유 4, 연유 4, 소금 약간]
# 32     [스팸 1/2개, 달걀 1개, 진간장 1~2t, 들기름 1T, 쌀밥 1+1/2공기]
# 33         [대파 20cm, 달걀 1개, 밥 1공기, 소금 1/10T, 후춧가루 약간]
# 34  [밥 1공기, 달걀 2개, 다진파 2T, 오일 1T, 물 200ml, 간장 1T, ...
# 35  [소시지 7~8개, 양파(소) 1개, 청고추 2개, 홍파프리카 1/2개, 달걀 1개...
# 36  [달걀 2개, 슬라이스햄 4장, 체더치즈 1장, 버터 1숟가락, 식빵 2장, 설탕 ...
# 37  [계란 2개, 표고버섯 2개, 전분가루 1T, 물 1T, 대파 2T, 다진마늘 1T...
# 38  [시금치 1단, 물, 소금 0.3숟가락, 된장 1숟가락, 다진마늘 0.5숟가락, 참...
# 39  [카레가루 4인분, 시금치 200g, 토마토 1개, 양파 1개, 다진마늘 1개, 오...
# 40  [시금치 1단, 대파흰부분 5cm, 버터 1Ts, 소금 2꼬집, 후추 약간, 식빵 ...
# 41  [베이컨 150g, 밥 1그릇, 대파 15cm, 당근 1/4개, 계란 2개, 치킨스...
# 42                [불린미역 50g, 달걀 3개, 간장 1작은술, 청주 1작은술]
# 43  [시금치반단,  달걀2개,  노른자1개,  우유250ml,  맥주1/4컵,  밀가루...
# 44                         [불린쌀15g,  물1컵,  데친 시금치10g]
# 45             [섬초,  다진마늘,  파,  통깨,  참기름,  들기름,  맛간장]
# 46  [시금치250g,  소금1/5큰술,  참기름1숟가락,  참깨1큰술,  다진 마늘1/2개]
# 47                                                 []
# 48                [불린쌀15g,  물2컵,  소고기15g,  (데친)시금치5g]
# 49  [시금치2단,  달걀1개,  양파1/8개,  홍고추1/4개,  마늘1개,  소금4꼬...
# 50  [시금치2줌,  베이컨2줄,  레몬즙(또는 레몬주스)1 T,  올리브유3T,  소금...
# 51  [카레가루한봉지,  양파큰거하나,  새우한팩,  시금치한줌,  요거트약간,  물3~5컵]
# 52       [라자냐1인분,  토마토소스1컵,  치즈약간,  시금치1단,  양유치즈1덩어리]
# 53                           [시금치1단,  참기름두큰술,  소금1약간]
# 54  [돼지고기베이컨4줄,  시금치1/2단,  방울토마토5개,  소금0.1숟가락,  식초...

# %%
def online_market(recipe_num) :
    recipe_num = int(recipe_num)
    selected_recipe = menu.iloc[recipe_num:recipe_num+1, :]
    selected_ing = selected_recipe['ingredient'].tolist()
    selected_ing = selected_ing[0]
    
    ## 필요한 재료(선택 레시피에는 있지만 내가 가지지 못한 재료) 추출
#     no_matter = []
    print("선택한 레시피의 재료들 :" ,selected_ing) 
    print("사용자가 가지고 있는 재료들 :", have_list)
    
    for i in selected_ing :
        if ('조금' in str(i)) or ('용' in str(i)):
            pass
        else :
            list1 = i.split(' ')
            a = list1[0]
            if a in have_list : 
                try :
                    b = ' '.join(list1)
                    selected_ing.remove(b)
                except :
                    pass

    no_matter = []
    for i in selected_ing :
        a = i.split(' ')
        no_matter.append(a[0])
        
    print("선택한 레시피의 재료 중에 사용자에게 없는 재료들 :", no_matter)
    
#     path = "C:\\Users\\dayoung\\Downloads\\chromedriver_win32\\chromedriver"
#     driver = webdriver.Chrome(path)
    driver = webdriver.Chrome()
    
    ## 마켓컬리 사이트 로그인
    driver.get("https://www.kurly.com/shop/member/login.php")
    element_id = driver.find_element_by_name("m_id")
    element_pw = driver.find_element_by_name("password")
    element_id.send_keys("ldyoung")
    element_pw.send_keys("dlsrhdwlsmd1234")
    driver.find_element_by_class_name('btn_type1').click()

    element_input = driver.find_element_by_name("sword")
    element_input.clear()

    ## 검색창 접근
    for want in no_matter:
        sword = driver.find_element_by_name('sword')  # 검색창
        sword.clear()  # 검색창에 쓰여진것 지우기
        sword.send_keys(want)  # 재료 리스트 입력
        btn_search = driver.find_elements_by_class_name('btn_search')[0]
        btn_search.click()  # '검색버튼' 클릭

        # 장바구니 클릭
        driver.implicitly_wait(100000)
        xpath = driver.find_element_by_xpath('//*[@id="goodsList"]/div[1]/div/ul/li[1]/div/div/div/button')
        xpath.click()

        # 장바구니 큰 틀
        inner_option = driver.find_elements_by_class_name('inner_option')[0]

        # 장바구니 추가 버튼
        final = inner_option.find_element_by_class_name('btn_type1')

        # 옵션 이름 리스트
        name = inner_option.find_elements_by_class_name('name')   
        name_list = []
        for i in name:
            name_list.append(i.text)

        for idx, item in enumerate(name_list):
            if len(name_list) == 1:  # name_list의 길이가 1인 경우

                if '품절' not in item:
                    final.click()
                else:
                    btn_close = driver.find_element_by_class_name('btn_close1')[0]  # 장바구니 닫기
                    btn_close.click()
                    break  

            else: # name_list의 길이가 2 이상인 경우
                if '품절' not in item:

                    if want in item:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[idx]  # 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기

                    else:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[0]  # 첫번째 항목 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 P담기

                    break

                else:  # 품절이 항목에 있는 경우

                    if '품절' in item:
                        pass
                    elif want in item:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[idx]  # 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기
                        break
                    else:    
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[0]  # 첫번째 항목 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기
                        break
                    
recipe_num = int(input("레시피 번호 선택 : "))
result = online_market(recipe_num)
# Out:
# 레시피 번호 선택 : 12
# 선택한 레시피의 재료들 : ['밥 1공기', '참치한캔 100g', '계란 2개', '소금 3꼬집', '후추 1/2스푼', '대파 1개']
# 사용자가 가지고 있는 재료들 : ['계란', '시금치']
# 선택한 레시피의 재료 중에 사용자에게 없는 재료들 : ['밥', '참치한캔', '소금', '후추', '대파']
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-15-2e3e77078a5d> in <module>
#     111
#     112 recipe_num = int(input("레시피 번호 선택 : "))
# --> 113 result = online_market(recipe_num)
#
# <ipython-input-15-2e3e77078a5d> in online_market(recipe_num)
#      59
#      60         # 장바구니 큰 틀
# ---> 61         inner_option = driver.find_elements_by_class_name('inner_option')[0]
#      62
#      63         # 장바구니 추가 버튼
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_class_name(self, name)
#     578             elements = driver.find_elements_by_class_name('foo')
#     579         """
# --> 580         return self.find_elements(by=By.CLASS_NAME, value=name)
#     581
#     582     def find_element_by_css_selector(self, css_selector):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1003         # Return empty list if driver returns null
#    1004         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
#    1007             'value': value})['value'] or []
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=84.0.4147.105)
